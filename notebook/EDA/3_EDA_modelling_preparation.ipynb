# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Introduction</strong></a></span><ul class="toc-item"><li><span><a href="#Dataset_limitations" data-toc-modified-id="Dataset_limitations-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Dataset_limitations</a></span></li><li><span><a href="#Primary_problem_statement*" data-toc-modified-id="Primary_problem_statement*-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Primary_problem_statement*</a></span></li><li><span><a href="#Data-dictionary" data-toc-modified-id="Data-dictionary-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Data dictionary</a></span></li><li><span><a href="#Raw-dataset" data-toc-modified-id="Raw-dataset-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Raw dataset</a></span></li></ul></li><li><span><a href="#Dataset-preprocessing-overview:-3-raw-.csv-files-->-merged.csv-->-vaers_clean.csv" data-toc-modified-id="Dataset-preprocessing-overview:-3-raw-.csv-files-->-merged.csv-->-vaers_clean.csv-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Dataset preprocessing overview: 3 raw .csv files -&gt; merged.csv -&gt; vaers_clean.csv</a></span><ul class="toc-item"><li><span><a href="#Summary-of-steps-to-combine-3-raw-.csv-files-->-merged.csv" data-toc-modified-id="Summary-of-steps-to-combine-3-raw-.csv-files-->-merged.csv-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Summary of steps to combine 3 raw .csv files -&gt; merged.csv</a></span><ul class="toc-item"><li><span><a href="#vax_df-(2021VAERSVAX.csv)" data-toc-modified-id="vax_df-(2021VAERSVAX.csv)-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>vax_df (2021VAERSVAX.csv)</a></span></li><li><span><a href="#symp_df-(2021VAERSSYMPTOMS.CSV)" data-toc-modified-id="symp_df-(2021VAERSSYMPTOMS.CSV)-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>symp_df (2021VAERSSYMPTOMS.CSV)</a></span></li><li><span><a href="#main_df-(2021VAERSDATA.CSV)" data-toc-modified-id="main_df-(2021VAERSDATA.CSV)-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>main_df (2021VAERSDATA.CSV)</a></span></li></ul></li><li><span><a href="#Summary-of-steps-from-merged.csv-->-vaers_clean.csv" data-toc-modified-id="Summary-of-steps-from-merged.csv-->-vaers_clean.csv-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Summary of steps from merged.csv -&gt; vaers_clean.csv</a></span><ul class="toc-item"><li><span><a href="#VAX_DATE" data-toc-modified-id="VAX_DATE-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>VAX_DATE</a></span></li><li><span><a href="#ONSET_DATE" data-toc-modified-id="ONSET_DATE-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>ONSET_DATE</a></span></li><li><span><a href="#NUMDAYS" data-toc-modified-id="NUMDAYS-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>NUMDAYS</a></span></li><li><span><a href="#AGE-variables" data-toc-modified-id="AGE-variables-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>AGE variables</a></span></li><li><span><a href="#SYMPTOM_TEXT" data-toc-modified-id="SYMPTOM_TEXT-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>SYMPTOM_TEXT</a></span></li><li><span><a href="#DIED" data-toc-modified-id="DIED-2.2.6"><span class="toc-item-num">2.2.6&nbsp;&nbsp;</span>DIED</a></span></li><li><span><a href="#L_THREAT" data-toc-modified-id="L_THREAT-2.2.7"><span class="toc-item-num">2.2.7&nbsp;&nbsp;</span>L_THREAT</a></span></li><li><span><a href="#HOSPITAL" data-toc-modified-id="HOSPITAL-2.2.8"><span class="toc-item-num">2.2.8&nbsp;&nbsp;</span>HOSPITAL</a></span></li><li><span><a href="#X_STAY" data-toc-modified-id="X_STAY-2.2.9"><span class="toc-item-num">2.2.9&nbsp;&nbsp;</span>X_STAY</a></span></li><li><span><a href="#DISABLE" data-toc-modified-id="DISABLE-2.2.10"><span class="toc-item-num">2.2.10&nbsp;&nbsp;</span>DISABLE</a></span></li><li><span><a href="#ER_ED_VISIT" data-toc-modified-id="ER_ED_VISIT-2.2.11"><span class="toc-item-num">2.2.11&nbsp;&nbsp;</span>ER_ED_VISIT</a></span></li><li><span><a href="#HISTORY" data-toc-modified-id="HISTORY-2.2.12"><span class="toc-item-num">2.2.12&nbsp;&nbsp;</span>HISTORY</a></span></li><li><span><a href="#ALLERGIES" data-toc-modified-id="ALLERGIES-2.2.13"><span class="toc-item-num">2.2.13&nbsp;&nbsp;</span>ALLERGIES</a></span></li><li><span><a href="#SYMP" data-toc-modified-id="SYMP-2.2.14"><span class="toc-item-num">2.2.14&nbsp;&nbsp;</span>SYMP</a></span></li></ul></li></ul></li><li><span><a href="#Target-variable" data-toc-modified-id="Target-variable-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Target variable</a></span><ul class="toc-item"><li><span><a href="#Columns-deemed-not-useful-for-current-problem-statement" data-toc-modified-id="Columns-deemed-not-useful-for-current-problem-statement-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Columns deemed not useful for current problem statement</a></span></li></ul></li><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Import-dataset" data-toc-modified-id="Import-dataset-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Import dataset</a></span><ul class="toc-item"><li><span><a href="#Inspect-dataset" data-toc-modified-id="Inspect-dataset-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Inspect dataset</a></span></li><li><span><a href="#Convert-data-types" data-toc-modified-id="Convert-data-types-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Convert data types</a></span></li></ul></li><li><span><a href="#Define-functions" data-toc-modified-id="Define-functions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Define functions</a></span></li><li><span><a href="#Distribution-of-target" data-toc-modified-id="Distribution-of-target-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Distribution of target</a></span><ul class="toc-item"><li><span><a href="#Checking-variables-that-made-up-the-composite-target-variable" data-toc-modified-id="Checking-variables-that-made-up-the-composite-target-variable-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Checking variables that made up the composite target variable</a></span></li></ul></li><li><span><a href="#Exploring-relationships-with-TARGET" data-toc-modified-id="Exploring-relationships-with-TARGET-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Exploring relationships with TARGET</a></span><ul class="toc-item"><li><span><a href="#Target_vs_HISTORY_DUM" data-toc-modified-id="Target_vs_HISTORY_DUM-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Target_vs_HISTORY_DUM</a></span></li><li><span><a href="#Target_vs_VAX_MANU" data-toc-modified-id="Target_vs_VAX_MANU-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Target_vs_VAX_MANU</a></span></li><li><span><a href="#Target_vs_ALERGIES_DUM" data-toc-modified-id="Target_vs_ALERGIES_DUM-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Target_vs_ALERGIES_DUM</a></span></li><li><span><a href="#Target_vs_AGE_YRS" data-toc-modified-id="Target_vs_AGE_YRS-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Target_vs_AGE_YRS</a></span></li><li><span><a href="#Target_vs_AGE_YRS_vs_HISTORY_DUM" data-toc-modified-id="Target_vs_AGE_YRS_vs_HISTORY_DUM-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Target_vs_AGE_YRS_vs_HISTORY_DUM</a></span></li><li><span><a href="#Target_vs_HYPERTENSION" data-toc-modified-id="Target_vs_HYPERTENSION-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Target_vs_HYPERTENSION</a></span></li><li><span><a href="#Target_vs_AGE_YRS_vs_HYPERTENSION" data-toc-modified-id="Target_vs_AGE_YRS_vs_HYPERTENSION-8.7"><span class="toc-item-num">8.7&nbsp;&nbsp;</span>Target_vs_AGE_YRS_vs_HYPERTENSION</a></span></li><li><span><a href="#Target_vs_DIABETES" data-toc-modified-id="Target_vs_DIABETES-8.8"><span class="toc-item-num">8.8&nbsp;&nbsp;</span>Target_vs_DIABETES</a></span></li><li><span><a href="#Target_vs_AGE_YRS_vs_DIABETES" data-toc-modified-id="Target_vs_AGE_YRS_vs_DIABETES-8.9"><span class="toc-item-num">8.9&nbsp;&nbsp;</span>Target_vs_AGE_YRS_vs_DIABETES</a></span></li><li><span><a href="#Target_vs_CKD" data-toc-modified-id="Target_vs_CKD-8.10"><span class="toc-item-num">8.10&nbsp;&nbsp;</span>Target_vs_CKD</a></span></li><li><span><a href="#Target_vs_AGE_YRS_vs_CKD" data-toc-modified-id="Target_vs_AGE_YRS_vs_CKD-8.11"><span class="toc-item-num">8.11&nbsp;&nbsp;</span>Target_vs_AGE_YRS_vs_CKD</a></span></li><li><span><a href="#Target_vs_CANCER" data-toc-modified-id="Target_vs_CANCER-8.12"><span class="toc-item-num">8.12&nbsp;&nbsp;</span>Target_vs_CANCER</a></span></li><li><span><a href="#Target_vs_AGE_YRS_vs_CANCER" data-toc-modified-id="Target_vs_AGE_YRS_vs_CANCER-8.13"><span class="toc-item-num">8.13&nbsp;&nbsp;</span>Target_vs_AGE_YRS_vs_CANCER</a></span></li><li><span><a href="#Target_vs_CARDIOVASCULAR" data-toc-modified-id="Target_vs_CARDIOVASCULAR-8.14"><span class="toc-item-num">8.14&nbsp;&nbsp;</span>Target_vs_CARDIOVASCULAR</a></span></li><li><span><a href="#Target_vs_AGE_YRS_vs_CARDIOVASCULAR" data-toc-modified-id="Target_vs_AGE_YRS_vs_CARDIOVASCULAR-8.15"><span class="toc-item-num">8.15&nbsp;&nbsp;</span>Target_vs_AGE_YRS_vs_CARDIOVASCULAR</a></span></li><li><span><a href="#Target_vs_V_ADMINBY" data-toc-modified-id="Target_vs_V_ADMINBY-8.16"><span class="toc-item-num">8.16&nbsp;&nbsp;</span>Target_vs_V_ADMINBY</a></span></li><li><span><a href="#Target_vs_gender" data-toc-modified-id="Target_vs_gender-8.17"><span class="toc-item-num">8.17&nbsp;&nbsp;</span>Target_vs_gender</a></span><ul class="toc-item"><li><span><a href="#Impute_missing/U_gender_as_F" data-toc-modified-id="Impute_missing/U_gender_as_F-8.17.1"><span class="toc-item-num">8.17.1&nbsp;&nbsp;</span>Impute_missing/U_gender_as_F</a></span></li></ul></li><li><span><a href="#Target_vs_AGE_YRS_vs_SEX" data-toc-modified-id="Target_vs_AGE_YRS_vs_SEX-8.18"><span class="toc-item-num">8.18&nbsp;&nbsp;</span>Target_vs_AGE_YRS_vs_SEX</a></span></li><li><span><a href="#Target_vs_STATE" data-toc-modified-id="Target_vs_STATE-8.19"><span class="toc-item-num">8.19&nbsp;&nbsp;</span>Target_vs_STATE</a></span></li><li><span><a href="#Target_vs_NUMDAYS_CAL" data-toc-modified-id="Target_vs_NUMDAYS_CAL-8.20"><span class="toc-item-num">8.20&nbsp;&nbsp;</span>Target_vs_NUMDAYS_CAL</a></span></li><li><span><a href="#Target_vs_COUNT_SYMPT" data-toc-modified-id="Target_vs_COUNT_SYMPT-8.21"><span class="toc-item-num">8.21&nbsp;&nbsp;</span>Target_vs_COUNT_SYMPT</a></span></li></ul></li><li><span><a href="#Correlation-matrix" data-toc-modified-id="Correlation-matrix-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Correlation matrix</a></span></li><li><span><a href="#Drop-columns-not-needed-for-modelling" data-toc-modified-id="Drop-columns-not-needed-for-modelling-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Drop columns not needed for modelling</a></span></li><li><span><a href="#Pairplots" data-toc-modified-id="Pairplots-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Pairplots</a></span></li></ul></div>

# %% [markdown]
# # **Introduction**
#
# [Vaccine Adverse Event Reporting System (VAERS)](https://vaers.hhs.gov/about.html) is a national early warning system to detect possible safety problems in U.S.-licensed vaccines.
#
# - It is a passive reporting system
#
#   - reports about adverse events are not automatically collected, but require a report to be filed to VAERS
#
# - Healthcare providers, vaccine manufacturers, and the public can submit reports to the system
#
# - A report often involves more than one vaccine and may involve more than one reported adverse event
#
# - VAERS is not designed to determine if a vaccine caused a health problem, but is especially useful for detecting unusual or unexpected patterns of adverse event reporting that might indicate a possible safety problem with a vaccine.
#
#
#
#
# **What this system is designed for:**
#
# VAERS is designed to rapidly detect unusual or unexpected patterns of adverse events (also known as “safety signals.”)
#
# - If a safety signal is found in VAERS, further studies can be done in safety systems such as:
#   - CDC’s Vaccine Safety Datalink (VSD) or
#   - Clinical Immunization Safety Assessment (CISA) project
#
# ---
#
#
# ## Dataset_limitations
#
# From the [Disclaimer](https://vaers.hhs.gov/data.html) and [VAERS dataset limitations](https://vaers.hhs.gov/data/dataguide.html):
#
# - The reports may contain information that is incomplete, inaccurate, coincidental, or unverifiable.
# - reports to VAERS are **voluntary**
#
#   - There is no need for any proof that the event was caused by the vaccine in order for VAERS to accept the report.
#
#   - VAERS accepts all reports (be it coincidental or truly caused by a vaccine) without judging whether the event was caused by the vaccine.
#
# - The number of reports alone cannot be interpreted or used to reach conclusions about the existence, severity, frequency, or rates of problems associated with vaccines.
#
#
# - VAERS data:
#   - is limited to vaccine adverse event reports received between 1990 and the most recent date for which data are available.
#   - **do not represent all known safety information for a vaccine** and should be interpreted in the context of other scientific information.
#
#   - VAERS data available to the public include only the **initial report data** to VAERS.
#     - Updated data which contains data from medical records and corrections reported during follow up are used by the government for analysis.
#     - However, for numerous reasons including data consistency, these amended data are not available to the public.
#
# ---
#
#
# ## Primary_problem_statement*
#
# Can we predict whether a mRNA vaccine recipient (reporting to VAERS) will experience a serious adverse side effect?
# A serious adverse side effect is defined as any one of the following:
#
# - if the vaccine recipient died,
# - if the vaccine recipient had a life threatening illness,
# - if the vaccine recipient had to be hospitalised as a result of the vaccination,
# - if the vaccine recipient's existing hospitalisation is prolonged as a result of the vaccination,
# - if the vaccine recipient was disabled,
# - if the vaccine recipient required a visit to the Emergency Department,
# - if the vaccine recipient experienced cardiac symptoms,
# - if the vaccine recipient experienced any serious (type 1 hypersensitivity) allergic reactions
#
#
# **in view of the above [limitations](#Dataset_limitations) of the dataset (especially the point that VAERS data do not represent all known safety information for a vaccine), there would be limited utility of the constructed predictive model. However, this repository is just meant to show the required preprocessing steps and pipeline contruction. This final supervised model dashboard is generic and able to display classification and regression models.*
#
#
# ## Data dictionary
#
# - [Data dictionary](https://vaers.hhs.gov/docs/VAERSDataUseGuide_November2020.pdf)
#
# ## Raw dataset
#
# Original data source: https://vaers.hhs.gov/data/datasets.html
#
# 3 datasets:
#
#   1. 2021VAERSDATA.CSV: VAERS report details organised by VAERS report Identification Number (VAERS_ID) as key variable
#
#   2. 2021VAERSVAX.CSV: vaccine details, organised by VAERS report Identification Number (VAERS_ID) as key variable
#
#   3. 2021VAERSSYMPTOMS.CSV: symptom details, organised by VAERS report Identification Number (VAERS_ID) as key variable
#
#
# **Dataset duration**: VAERS reports from 1 Jan 2021 to 31 Mar 2021
#
# # Dataset preprocessing overview: 3 raw .csv files -> merged.csv -> vaers_clean.csv
#
#
# ## Summary of steps to combine 3 raw .csv files -> merged.csv
#
# ### vax_df (2021VAERSVAX.csv)
#
# 1. Select only rows with VAX_MANU values that contain "MODERNA" or "PFIZER\BIONTECH"
# 2. Drop the remaining duplicated rows, subset based on the unique key 'VAERS_ID"
# 3. Keep only VAERS_ID and VAX_MANU columns
# 4. Merge with main dataframe based on the unique key 'VAERS_ID"
#
# ### symp_df (2021VAERSSYMPTOMS.CSV)
#
# 1. Convert the data type to string type
# 2. Fill missing values with blank string ("") so that we can use string methods safely (string methods will raise exceptions when there are NaN)
# 3. Join the symptom columns (SYMPTOM1, SYMPTOM2, SYMPTOM3, SYMPTOM4, SYMPTOM5) into one column 'SYMP', with each symptom separated by a comma (",") to differentiate between the different symptoms
# 4. Remove excess commas (",,") for blank symptoms
# 5. Aggregate multiple rows of the same VAERS_ID into one row via grouping by 'VAERS_ID'
# 6. Create a new column 'COUNT_SYMP' by splitting the strings at the delimitor (',') and then counting the number of elements in 'SYMP'
# 7. Use only 'VAERS_ID', 'SYMP' and 'COUNT_SYMPT' for merging with the main dataframe
#
# ### main_df (2021VAERSDATA.CSV)
#
# 1. Convert date columns to datetime format
# 2. Subset main_df by selecting rows with RECVDATE less than 1 Apr 2021 (i.e dataset date range will be from 1 Jan 2021 to 31 Mar 2021)
# 3. Merge into 1 main dataframe via 2 steps:
#   - Step1: merge main_df with vax_df on the unique key 'VAERS_ID',
#   - Step2: then merge with symp_df on the unique key 'VAERS_ID'
#
#
# ## Summary of steps from merged.csv -> vaers_clean.csv
#
# ### VAX_DATE
# - Dropped 781 rows (0.42%) for VAX_DATE < 2020-12-11 (as COVID-19 vaccines emergency use authorisation were only issued on 11 Dec 2020: [news release](https://www.fda.gov/news-events/press-announcements/fda-takes-key-action-fight-against-covid-19-issuing-emergency-use-authorization-first-covid-19))
# - Dropped 3187 (1.8%) NA rows for VAX_DATE
#
# ### ONSET_DATE
# - Dropped 359 rows (0.19%) for ONSET_DATE < 2020-12-11,
# - Dropped 4170 (2.35%) NA rows for ONSET_DATE
# - replaced 1273 rows that are less than VAX_DATE with VAX_DATE value
#
# ### NUMDAYS
# - Recalculated NUMDAYS from ONSET_DATE - VAX_DATE after erroneous rows have been dropped for those columns
#
# ### AGE variables
# - Dropped CAGE_MO (10.0% missing) and CAGE_YR (~100% missing) due to redundancy of information and extent of missing values in those columns,
# - Dropped 95 rows (0.05%) for AGE_YRS < 12 years old (COVID vaccines during the dataset period 1 Jan 2021 - 31 Mar 2021 were only authorised for age 12 and above)
# - Dropped 6374 (3.59%) NA rows for AGE_YRS
#
# ### SYMPTOM_TEXT
# - Dropped 5 rows with missing values
#
# ### DIED
# - Imputed 167341 (98.7%) missing values with 'N' as missing values indicate that the event did not occur
#
# ### L_THREAT
# - Imputed 167750 (98.95%) missing values with 'N' as missing values indicate that the event did not occur
#
# ### HOSPITAL
# - Imputed 163775 (96.6%) missing values with 'N' as missing values indicate that the event did not occur
#
# ### X_STAY
# - Imputed 169465 (99.96%) missing values with 'N' as missing values indicate that the event did not occur
#
# ### DISABLE
# - Imputed 168292 (99.27%) missing values with 'N' as missing values indicate that the event did not occur
#
# ### ER_ED_VISIT
# - Imputed 148686 (87.7%) missing values with 'N' as missing values indicate that the event did not occur
#
# ### HISTORY
# - lowercase strings,
# - engineered new features based on matching with substrings:
#   - HYPERTENSION,
#   - DIABETES,
#   - CANCER,
#   - CKD,
#   - CARDIOVASCULAR
# - created new feature HISTORY_DUM with 0 = no medical history, 1 = at least 1 medical history
#   - 1. Replace variations of None synonyms to np.nan,
#   - 2. Replace np.nan with 0 (includes existing NaNs), and replace all character strings with 1
#
# ### ALLERGIES
# - lowercase strings
# - created new feature ALLERGIES_DUM with 0 = no allergies, 1 = at least 1 known allergy via the following steps:
#   - 1. Replace variations of None synonyms to np.nan,
#   - 2. Replace np.nan with 0 (includes existing NaNs), and replace all character strings with 1
#
# ### SYMP
# - This was an engineered feature from the original 5 SYMPTOM columns in 2021VAERSSYMPTOMS.CSV
# - 1. Drop rows that indicate medical/administrative related errors, or rows that indicate no adverse event.
# 2. Engineered the following new features by matching substrings:
# - SYMP_SERIOUS_ALLERGY: symptoms indicating serious allergic reactions such as anaphylaxis
# - SYMP_DEATH: symptoms indicating death. This is just in case there were missing entry errors for DIED variable
# - SYMP_CARDIAC: cardiac related symptoms
#
#
# # Target variable
#
# - Composite variable created from the following columns to answer the [primary problem statement](#Primary_problem_statement*):
#
#
# ```
#     target_composite_list = ['DIED', 'L_THREAT', 'HOSPITAL', 'X_STAY', 'DISABLE',
#                              'ER_ED_VISIT', 'SYMP_DEATH', 'SYMP_CARDIAC', 'SYMP_SERIOUS_ALLERGY']
#
#     df['composite'] = 0 # dummy numeric series for addition in the for loop
#
#     for col in target_composite_list:
#
#         df['composite'] += df[col]
#
#     df['TARGET_SERIOUS_ADVERSE'] = np.where(
#         df['composite'] == 0,
#         'No',
#         'Yes'
#     )
#
# ```
# - Representation of **TARGET_SERIOUS_ADVERSE**:
#   - 'Yes': at least 1 serious adverse side effect reported,
#   - 'No': no serious adverse side effect reported.
#
#
#
# ## Columns deemed not useful for current problem statement
#
# As stated in the [initial sanity checks](Initial_sanity_checks_combined_dataset.ipynb), the following columns/variables can be dropped as they are not useful for the current problem statement:
#
# - OFC_VISIT (visit to a doctor or healthcare professional can be for a multitide of reasons)
# - BIRTH_DEFECT (unable to determine percentage of pregnant women in the dataset)
#
# - Redundant/deprecated information:
#   - CAGE_MO
#   - CAGE_YRS
#   - DATEDIED
#   - RECVDATE
#   - RPT_DATE
#   - TODAYS_DATE
#   - CUR_ILL (information can already be found in HISTORY)
#   - SPLITTYPE
#   - FORM_VERS
#   - ER_VISIT (deprecated in updated form)
#
# - Too many missing values or variable with high cardinality, limited utility for current problem statement:
#   - V_FUNDBY
#   - PRIOR_VAX
#   - SPLITTYPE
#   - STATE
#
# - Feature can only be obtained only after the adverse event
#   - HOSPDAYS
#   - RECOVD
#
# - Unstructued text, unable to clean properly
#   - LAB_DATA
#   - OTHER_MEDS

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %% [markdown]
# # Import dataset

# %%
clean_filepath = Path.cwd().parents[1] / 'data/processed/vaers_clean.csv'
df = pd.read_csv(clean_filepath, low_memory=False)

# %% [markdown]
# ## Inspect dataset

# %%
print(f"Number of rows, number of columns: {df.shape}")
# Out:
# Number of rows, number of columns: (169537, 52)

# %%
df.columns
# Out:
# Index(['VAERS_ID', 'RECVDATE', 'STATE', 'AGE_YRS', 'CAGE_YR', 'CAGE_MO', 'SEX',
#        'RPT_DATE', 'SYMPTOM_TEXT', 'DIED', 'DATEDIED', 'L_THREAT', 'ER_VISIT',
#        'HOSPITAL', 'HOSPDAYS', 'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE',
#        'ONSET_DATE', 'NUMDAYS', 'LAB_DATA', 'V_ADMINBY', 'V_FUNDBY',
#        'OTHER_MEDS', 'CUR_ILL', 'HISTORY', 'PRIOR_VAX', 'SPLTTYPE',
#        'FORM_VERS', 'TODAYS_DATE', 'BIRTH_DEFECT', 'OFC_VISIT', 'ER_ED_VISIT',
#        'ALLERGIES', 'VAX_MANU', 'SYMP', 'COUNT_SYMPT', 'NUMDAYS_CAL',
#        'HISTORY_DUM', 'ALLERGIES_DUM', 'HYPERTENSION', 'DIABETES', 'CANCER',
#        'CKD', 'CARDIOVASCULAR', 'SYMP_SERIOUS_ALLERGY', 'SYMP_DEATH',
#        'SYMP_CARDIAC', 'NUR_HOME', 'composite', 'TARGET_SERIOUS_ADVERSE'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169537 entries, 0 to 169536
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   VAERS_ID                169537 non-null  int64
#  1   RECVDATE                169537 non-null  object
#  2   STATE                   154516 non-null  object
#  3   AGE_YRS                 169537 non-null  float64
#  4   CAGE_YR                 159790 non-null  float64
#  5   CAGE_MO                 154 non-null     float64
#  6   SEX                     169537 non-null  object
#  7   RPT_DATE                176 non-null     object
#  8   SYMPTOM_TEXT            169536 non-null  object
#  9   DIED                    169537 non-null  int64
#  10  DATEDIED                2110 non-null    object
#  11  L_THREAT                169537 non-null  int64
#  12  ER_VISIT                21 non-null      object
#  13  HOSPITAL                169537 non-null  int64
# ...

# %% [markdown]
# ## Convert data types

# %% [markdown]
# The engineered features and variables used to form the composite target variable are in float (1, 0) dtypes so that they could be used directly for modelling.
# However, for the current EDA phase, mapping the 1 and 0 to 'Yes' and 'No' would be more helpful in visualizing relationships.

# %%
labels = {
    0: 'No',
    1: 'Yes'
}

TARGET_COMPOSITE = ['DIED', 'L_THREAT', 'HOSPITAL', 'X_STAY', 'DISABLE', 'ER_ED_VISIT', 'SYMP_DEATH', 
                   'SYMP_CARDIAC', 'SYMP_SERIOUS_ALLERGY']

engineered_features = ['HYPERTENSION', 'DIABETES', 'CANCER', 'CKD', 'CARDIOVASCULAR', 'HISTORY_DUM',
                       'ALLERGIES_DUM', 'NUR_HOME']

cols_to_convert = TARGET_COMPOSITE + engineered_features

# %%
for col in cols_to_convert:
    
    df[col] = df[col].map(labels)
    df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169537 entries, 0 to 169536
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   VAERS_ID                169537 non-null  int64
#  1   RECVDATE                169537 non-null  object
#  2   STATE                   154516 non-null  object
#  3   AGE_YRS                 169537 non-null  float64
#  4   CAGE_YR                 159790 non-null  float64
#  5   CAGE_MO                 154 non-null     float64
#  6   SEX                     169537 non-null  object
#  7   RPT_DATE                176 non-null     object
#  8   SYMPTOM_TEXT            169536 non-null  object
#  9   DIED                    169537 non-null  category
#  10  DATEDIED                2110 non-null    object
#  11  L_THREAT                169537 non-null  category
#  12  ER_VISIT                21 non-null      object
# ...

# %% [markdown]
# # Define functions

# %%
def check_col_missing(df: pd.DataFrame,
                      col: str) -> pd.DataFrame:
    """
    Checks missing values of a column of a dataset, prints output to the console
    Returns a subset of the dataset containing the missing values for inspection 
    
    Args:
        df ([pd.Dataframe): Pandas DataFrame
        col ([str]): column name in the dataframe
    
    Returns:
        df_subset ([pd.DataFrame]): subset of dataframe containing the mising values for inspection
        
    """
    
    print(f"No. of missing/NaN for {col} out of {len(df)} rows: {df[col].isnull().sum()} rows")
    print(f"% missing/NaN for {col} out of {len(df)} rows: {round(df[col].isnull().sum()/len(df[col])*100)} %")
    
    df_subset = df[df[col].isnull()]
    
    return df_subset


def plot_dist(df: pd.DataFrame,
              col: str) -> None:
    """Plots the distribution of a column in a dataframe using a histogram and KDE plot

    Args:
        df (pd.DataFrame): pandas DataFrame
        col (str): Column name
        hue (str): name of column to use for hue argument in histplot. Defaults to None. 
    """
    sns.set()
    sns.set_style("white") 

    f, axes = plt.subplots(nrows=1,ncols=2, figsize=(16,5))
    f.suptitle(f'Distribution of {col}')
    axes[0].set_title("Histogram")
    axes[1].set_title("Kernel density estimate")

    ax= sns.histplot(data= df, x=col, ax=axes[0], bins=20)
    ax= sns.kdeplot(data= df, x=col, ax=axes[1])

    plt.show()

def plot_box(df: pd.DataFrame,
             x: str,
             y: str = None,
             hue: str = None,
             figsize: tuple = None) -> None:
    """Plots a boxplot

    Args:
        df (pd.DataFrame): pandas DataFrame
        x (str): Column variable for x axis of boxplot
        y (str): Column vairable for y axis of boxplot. Defaults to None. 
        hue (str): name of column to use for hue argument in boxplot. Defaults to None. 
    """
    sns.set()
    sns.set_style("white")
    
    if figsize:
        plt.figure(figsize=figsize)
    else:
        plt.figure(figsize=(8,6))
        
    if y:
        plt.title(f'Boxplot of {y} against {x}')
    else:
        plt.title(f'Boxplot of {x}')
        
    sns.boxplot(data=df, x=x, y=y, hue=hue)
    plt.show()


def plot_cat(df: pd.DataFrame, 
             col: str, 
             hue: str = None,
             title: str = None, 
             figsize: tuple = None) -> None:

    """Plots total counts and annotated percentages for each category 
    of a specified column of the DataFrame

    Args:
        df (pd.DataFrame): pandas DataFrame
        col (str): column to plot
        hue (str): name of column to use for hue argument in countplot. Defaults to None. 
        title (str, optional): Title for plot. Defaults to None.
        figsize (tuple, optional): Size of figure. Defaults to figsize=(8,6) if no values are stated. 
    """
    
    sns.set_palette('Set2')
    sns.set_style("white")

    if figsize:
        plt.figure(figsize=figsize)
    else:
        plt.figure(figsize=(14,6))

    ax = sns.countplot(x=col, data=df, hue=hue)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/len(df[col]))
        x = p.get_x() + p.get_width() / 2 
        y = p.get_y() + p.get_height()
        plt.annotate(percentage, (x, y),ha='center')
    if title:
        plt.title(title)
    else:
        plt.title(f'Total counts with annotated percentages for {col}')
    plt.show()


def plot_bar(df: pd.DataFrame, 
             x: str, 
             y: str,
             hue: str = None,
             title: str = None, 
             figsize: tuple = None) -> None:

    """Plots a bar plot with annotated values. 

    Args:
        df (pd.DataFrame): pandas DataFrame
        x (str): column variable to use for x axis
        y (str): column variable to use for y axis
        hue (str): name of column to use for hue argument in barplot. Defaults to None. 
        title (str, optional): Title for plot. Defaults to None.
        figsize (tuple, optional): Size of figure. Defaults to figsize=(8,6) if no values are stated. 
    """
    if figsize:
        plt.figure(figsize=figsize)
    else:
        plt.figure(figsize=(14,6))

    ax = sns.barplot(data=df, x=x, y=y, hue=hue)
   
    if title:
        plt.title(title)
    else:
        plt.title(f'Bar plot of {y} against {x}')

    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
        ax.annotate('{:.2f}'.format(height), (x + width/2, y + height*1.01), ha='center')
    plt.show()

    
def check_continuous(df: pd.DataFrame,
                     col: str) -> None:
    """Checks a continuous variable of a data frame
    Prints out summary statistics, missing values and 
    Plots the distribution of the variable

    Args:
        df (pd.DataFrame): pandas DataFrame
        col (str): name of column to evaluate summary statistics and plot distributions
    """
    print(df[col].describe())
    
    check_col_missing(df, col)
    
    plot_dist(df,col)
    
    plot_box(df=df, x=col)


def check_cat(df: pd.DataFrame,
              col: str) -> None:
    """
    - Checks the number of unique counts for each category for a column in a dataframe and 
    prints out counts for each category.
    
    - Checks missing values of a column of a dataset, prints output to the console 
    - uese helper function check_col_missing
    
    Args:
        df ([pd.Dataframe): Pandas DataFrame
        col ([str]): column name in the dataframe
    
    """
    print(f'Counts for each category for {col} out of {df[col].nunique()} categories: \n' +\
          f'{df[col].value_counts()} \n')
    
    print(f'proportion for each category for {col} out of {df[col].nunique()} categories: \n' +\
          f'{df[col].value_counts(normalize=True)} \n')
    
    check_col_missing(df, col)

# %% [markdown]
# # Distribution of target

# %%
check_cat(df, 'TARGET_SERIOUS_ADVERSE')
# Out:
# Counts for each category for TARGET_SERIOUS_ADVERSE out of 2 categories:
# No     136026
# Yes     33511
# Name: TARGET_SERIOUS_ADVERSE, dtype: int64
#
# proportion for each category for TARGET_SERIOUS_ADVERSE out of 2 categories:
# No     0.802338
# Yes    0.197662
# Name: TARGET_SERIOUS_ADVERSE, dtype: float64
#
# No. of missing/NaN for TARGET_SERIOUS_ADVERSE out of 169537 rows: 0 rows
# % missing/NaN for TARGET_SERIOUS_ADVERSE out of 169537 rows: 0.0 %

# %%
plot_cat(df, 'TARGET_SERIOUS_ADVERSE', figsize=(8,6))

# %% [markdown]
# ## Checking variables that made up the composite target variable

# %%
# %matplotlib inline

TARGET_COMPOSITE = ['DIED', 'L_THREAT', 'HOSPITAL', 'X_STAY', 'DISABLE', 'ER_ED_VISIT', 'SYMP_DEATH', 
                   'SYMP_CARDIAC', 'SYMP_SERIOUS_ALLERGY']

plt.figure(figsize=(16,36))

sns.set_theme(style="white")

for index, variable in enumerate(TARGET_COMPOSITE):
    plt.subplot(9,2,index + 1)
    
    sns.set_palette('Set2')
    ax=sns.countplot(x=df[variable], data=df)
    
    # remove lines from the plots
    sns.despine(top=True,right=True,left=True)
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)
    
    # label the charts with percentage
    for p in ax.patches:
        percentage = '{:.2f}%'.format(100 * p.get_height()/len(df[variable]))
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        plt.annotate(percentage, (x, y),ha='center')
        plt.title(TARGET_COMPOSITE[index])
        ax.set_xlabel('')

# %% [markdown]
# # Exploring relationships with TARGET

# %% [markdown]
# In this EDA, we will refrain from using p-values of null hypothesis significance testing as the large sample size (169536 rows) can affect the p-value obtained. Instead, we will explore all possible relationships, and then evaluate feature effects and importance after the modelling phase (i.e. via SHAP(SHapley Additive exPlanations) summary plot or impurity-based feature importance scores) using the Supervised Model Dashboard.

# %% [markdown]
# ## Target_vs_HISTORY_DUM

# %% [markdown]
# Checking distribution of patients with previous medical history first:

# %%
check_cat(df, 'HISTORY_DUM')
# Out:
# Counts for each category for HISTORY_DUM out of 2 categories:
# Yes    87081
# No     82456
# Name: HISTORY_DUM, dtype: int64
#
# proportion for each category for HISTORY_DUM out of 2 categories:
# Yes    0.51364
# No     0.48636
# Name: HISTORY_DUM, dtype: float64
#
# No. of missing/NaN for HISTORY_DUM out of 169537 rows: 0 rows
# % missing/NaN for HISTORY_DUM out of 169537 rows: 0.0 %

# %% [markdown]
# **Are the numbers of cases with at least 1 vaccine-related serious adverse effects possibly higher in patients with previous medical history?**

# %%
plot_cat(
    df = df, 
    col = 'HISTORY_DUM', 
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Number of patients who experienced at least 1 serious adverse effect, segregated by presence/absence of previous medical history'
)

# %%
# Checking counts after grouping by 'HISTORY_DUM':

df.groupby('HISTORY_DUM').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts().\
    rename('counts').\
    reset_index()
# Out:
#   HISTORY_DUM TARGET_SERIOUS_ADVERSE  counts
# 0          No                     No   68409
# 1          No                    Yes   14047
# 2         Yes                     No   67617
# 3         Yes                    Yes   19464

# %% [markdown]
# **Are the proportion of cases with at least 1 vaccine-related serious adverse side effects possibly higher in patients with previous medical history?**

# %%
history_p = df.groupby('HISTORY_DUM').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
history_p
# Out:
#   HISTORY_DUM TARGET_SERIOUS_ADVERSE  proportion
# 0          No                     No    0.829642
# 1          No                    Yes    0.170358
# 2         Yes                     No    0.776484
# 3         Yes                    Yes    0.223516

# %%
plot_bar(
    df = history_p, 
    x = 'HISTORY_DUM',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients who experienced at least 1 serious adverse side effect, grouped by previous medical history'
)

# %% [markdown]
# ## Target_vs_VAX_MANU

# %%
check_cat(df, 'VAX_MANU')
# Out:
# Counts for each category for VAX_MANU out of 2 categories:
# MODERNA            100912
# PFIZER\BIONTECH     68625
# Name: VAX_MANU, dtype: int64
#
# proportion for each category for VAX_MANU out of 2 categories:
# MODERNA            0.595221
# PFIZER\BIONTECH    0.404779
# Name: VAX_MANU, dtype: float64
#
# No. of missing/NaN for VAX_MANU out of 169537 rows: 0 rows
# % missing/NaN for VAX_MANU out of 169537 rows: 0.0 %

# %% [markdown]
# **Are the number of cases with at least 1 vaccine-related serious adverse effects possibly higher for different vaccine manufacturers?**

# %%
plot_cat(
    df = df, 
    col = 'VAX_MANU', 
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Number of cases who experienced at least 1 serious adverse effect, segregated by vaccine manufacturer'
)

# %% [markdown]
# ## Target_vs_ALERGIES_DUM

# %%
check_cat(df, 'ALLERGIES_DUM')
# Out:
# Counts for each category for ALLERGIES_DUM out of 2 categories:
# No     97404
# Yes    72133
# Name: ALLERGIES_DUM, dtype: int64
#
# proportion for each category for ALLERGIES_DUM out of 2 categories:
# No     0.574529
# Yes    0.425471
# Name: ALLERGIES_DUM, dtype: float64
#
# No. of missing/NaN for ALLERGIES_DUM out of 169537 rows: 0 rows
# % missing/NaN for ALLERGIES_DUM out of 169537 rows: 0.0 %

# %% [markdown]
# **Are there perhaps more cases of at least 1 serious vaccine-related adverse side effect in people with previous allergies?**

# %%
plot_cat(
    df = df, 
    col = 'ALLERGIES_DUM', 
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Number of cases who experienced at least 1 serious adverse effect, segregated by any previous allergies'
)

# %%
# Checking counts after grouping by ALLERGIES 

df.groupby('ALLERGIES_DUM').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts().\
    rename('counts').\
    reset_index()
# Out:
#   ALLERGIES_DUM TARGET_SERIOUS_ADVERSE  counts
# 0            No                     No   78907
# 1            No                    Yes   18497
# 2           Yes                     No   57119
# 3           Yes                    Yes   15014

# %% [markdown]
# Checking proportions:

# %%
allergy_p = df.groupby('ALLERGIES_DUM').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
allergy_p
# Out:
#   ALLERGIES_DUM TARGET_SERIOUS_ADVERSE  proportion
# 0            No                     No    0.810100
# 1            No                    Yes    0.189900
# 2           Yes                     No    0.791857
# 3           Yes                    Yes    0.208143

# %%
plot_bar(
    df = allergy_p, 
    x = 'ALLERGIES_DUM',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients who experienced least 1 serious adverse side effect, grouped by previous allergies'
)

# %% [markdown]
# Known allergy to the vaccine or vaccine components is an absolute **contraindication** to vaccination. If the vaccine recipient had a known allergy to the vaccine and yet he/she was still given the vaccine, it would simply be medical negligence.
#
# So it is likely that those with a history of allergies were not allergic to the vaccine and had other types of mild allergies; hence history of allergies is not associated with serious adverse effect as visualised above.

# %% [markdown]
# ## Target_vs_AGE_YRS

# %%
check_continuous(df, 'AGE_YRS')
# Out:
# count    169537.000000
# mean         52.382341
# std          17.489319
# min          13.000000
# 25%          38.000000
# 50%          52.000000
# 75%          66.000000
# max         119.000000
# Name: AGE_YRS, dtype: float64
# No. of missing/NaN for AGE_YRS out of 169537 rows: 0 rows
# % missing/NaN for AGE_YRS out of 169537 rows: 0.0 %

# %% [markdown]
# **Are the patients who experienced at least 1 vaccine-related serious adverse side effect older?**

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'AGE_YRS'
)

# %% [markdown]
# ## Target_vs_AGE_YRS_vs_HISTORY_DUM

# %% [markdown]
# **Does age and previous medical history affect whether one experienced at least 1 serious adverse side effect?**

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'AGE_YRS',
    hue = 'HISTORY_DUM', 
    figsize= (12,8)
)

# %% [markdown]
# ## Target_vs_HYPERTENSION

# %%
check_cat(df, 'HYPERTENSION')
# Out:
# Counts for each category for HYPERTENSION out of 2 categories:
# No     149537
# Yes     20000
# Name: HYPERTENSION, dtype: int64
#
# proportion for each category for HYPERTENSION out of 2 categories:
# No     0.882032
# Yes    0.117968
# Name: HYPERTENSION, dtype: float64
#
# No. of missing/NaN for HYPERTENSION out of 169537 rows: 0 rows
# % missing/NaN for HYPERTENSION out of 169537 rows: 0.0 %

# %% [markdown]
# **Is there possibly a highter proportion of patients with hypertension who experienced at least 1 serious adverse vaccine-related side effect?**

# %%
htn_p = df.groupby('HYPERTENSION').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
htn_p
# Out:
#   HYPERTENSION TARGET_SERIOUS_ADVERSE  proportion
# 0           No                     No    0.811157
# 1           No                    Yes    0.188843
# 2          Yes                     No    0.736400
# 3          Yes                    Yes    0.263600

# %%
plot_bar(
    df = htn_p, 
    x = 'HYPERTENSION',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients with hypertension who experienced least 1 serious adverse side effect'
)

# %% [markdown]
# ## Target_vs_AGE_YRS_vs_HYPERTENSION

# %% [markdown]
# **Were there more older patients with hypertension who experienced at least 1 serious vaccine-related adverse side effect?**

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'AGE_YRS',
    hue = 'HYPERTENSION', 
    figsize= (12,8)
)

# %% [markdown]
# ## Target_vs_DIABETES

# %%
check_cat(df, 'DIABETES')
# Out:
# Counts for each category for DIABETES out of 2 categories:
# No     158526
# Yes     11011
# Name: DIABETES, dtype: int64
#
# proportion for each category for DIABETES out of 2 categories:
# No     0.935053
# Yes    0.064947
# Name: DIABETES, dtype: float64
#
# No. of missing/NaN for DIABETES out of 169537 rows: 0 rows
# % missing/NaN for DIABETES out of 169537 rows: 0.0 %

# %% [markdown]
# **Is there a highter proportion of patients with diabetes who experienced at least 1 vaccine-related serious adverse side effect?**

# %%
dm_p = df.groupby('DIABETES').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
dm_p
# Out:
#   DIABETES TARGET_SERIOUS_ADVERSE  proportion
# 0       No                     No    0.807558
# 1       No                    Yes    0.192442
# 2      Yes                     No    0.727182
# 3      Yes                    Yes    0.272818

# %%
plot_bar(
    df = dm_p, 
    x = 'DIABETES',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients with diabetes who experienced least 1 serious adverse side effect'
)

# %% [markdown]
# ## Target_vs_AGE_YRS_vs_DIABETES

# %% [markdown]
# **Were there more older patients with diabetes who experienced at least 1 vaccine-related adverse side effect?**

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'AGE_YRS',
    hue = 'DIABETES',
    figsize= (12,8)
)

# %% [markdown]
# ## Target_vs_CKD

# %% [markdown]
# **Was there a highter proportion of patients with chronic kidney disease who experienced least 1 serious adverse side effect?**

# %%
check_cat(df, 'CKD')
# Out:
# Counts for each category for CKD out of 2 categories:
# No     166544
# Yes      2993
# Name: CKD, dtype: int64
#
# proportion for each category for CKD out of 2 categories:
# No     0.982346
# Yes    0.017654
# Name: CKD, dtype: float64
#
# No. of missing/NaN for CKD out of 169537 rows: 0 rows
# % missing/NaN for CKD out of 169537 rows: 0.0 %

# %%
ckd_p = df.groupby('CKD').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion')\
    .reset_index()

# %%
ckd_p
# Out:
#    CKD TARGET_SERIOUS_ADVERSE  proportion
# 0   No                     No    0.805457
# 1   No                    Yes    0.194543
# 2  Yes                     No    0.628801
# 3  Yes                    Yes    0.371199

# %%
plot_bar(
    df = ckd_p, 
    x = 'CKD',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients with chronic kidney disease who experienced least 1 serious adverse side effect'
)

# %% [markdown]
# ## Target_vs_AGE_YRS_vs_CKD

# %% [markdown]
# **Were there more older patients with chronic kidney disease who experienced at least 1 vaccine-related serious adverse side effect?**

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'AGE_YRS',
    hue = 'CKD', 
    figsize= (12,8)
)

# %% [markdown]
# ## Target_vs_CANCER

# %% [markdown]
# **Was there a higher proportion of patients with cancer who experienced least 1 vaccine-related serious adverse side effect?**

# %%
check_cat(df, 'CANCER')
# Out:
# Counts for each category for CANCER out of 2 categories:
# No     166188
# Yes      3349
# Name: CANCER, dtype: int64
#
# proportion for each category for CANCER out of 2 categories:
# No     0.980246
# Yes    0.019754
# Name: CANCER, dtype: float64
#
# No. of missing/NaN for CANCER out of 169537 rows: 0 rows
# % missing/NaN for CANCER out of 169537 rows: 0.0 %

# %%
cancer_p = df.groupby('CANCER').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
cancer_p
# Out:
#   CANCER TARGET_SERIOUS_ADVERSE  proportion
# 0     No                     No    0.803746
# 1     No                    Yes    0.196254
# 2    Yes                     No    0.732457
# 3    Yes                    Yes    0.267543

# %%
plot_bar(
    df = cancer_p, 
    x = 'CANCER',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients with cancer who experienced least 1 serious adverse side effect'
)

# %% [markdown]
# ## Target_vs_AGE_YRS_vs_CANCER

# %% [markdown]
# **Did more older patients with cancer experience at least 1 vaccine-related adverse side effect?**

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'AGE_YRS',
    hue = 'CANCER', 
    figsize= (12,8)
)

# %% [markdown]
# ## Target_vs_CARDIOVASCULAR

# %% [markdown]
# **Was there a higher proportion of patients with cardiovascular disease who experienced least 1 serious adverse side effect?**

# %%
check_cat(df, 'CARDIOVASCULAR')
# Out:
# Counts for each category for CARDIOVASCULAR out of 2 categories:
# No     161907
# Yes      7630
# Name: CARDIOVASCULAR, dtype: int64
#
# proportion for each category for CARDIOVASCULAR out of 2 categories:
# No     0.954995
# Yes    0.045005
# Name: CARDIOVASCULAR, dtype: float64
#
# No. of missing/NaN for CARDIOVASCULAR out of 169537 rows: 0 rows
# % missing/NaN for CARDIOVASCULAR out of 169537 rows: 0.0 %

# %%
cvs_p = df.groupby('CARDIOVASCULAR').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
cvs_p
# Out:
#   CARDIOVASCULAR TARGET_SERIOUS_ADVERSE  proportion
# 0             No                     No    0.809650
# 1             No                    Yes    0.190350
# 2            Yes                     No    0.647182
# 3            Yes                    Yes    0.352818

# %%
plot_bar(
    df = cvs_p, 
    x = 'CARDIOVASCULAR',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients with cardiovascular disease who experienced least 1 serious adverse side effect'
)

# %% [markdown]
# ## Target_vs_AGE_YRS_vs_CARDIOVASCULAR

# %% [markdown]
# **Were there more older patients with cardiovascular disease who experienced at least 1 vaccine-related serious adverse effect?**

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'AGE_YRS',
    hue = 'CARDIOVASCULAR', 
    figsize= (12,8)
)

# %% [markdown]
# ## Target_vs_V_ADMINBY

# %% [markdown]
# **Does the facility where the vaccine was administered affect whether one experienced at least 1 serious adverse side effect?**

# %%
check_cat(df, 'V_ADMINBY')
# Out:
# Counts for each category for V_ADMINBY out of 9 categories:
# PVT    56576
# OTH    28823
# PUB    23360
# UNK    21046
# PHM    16442
# WRK    11418
# SEN     5871
# SCH     3174
# MIL     2827
# Name: V_ADMINBY, dtype: int64
#
# proportion for each category for V_ADMINBY out of 9 categories:
# PVT    0.333709
# OTH    0.170010
# PUB    0.137787
# UNK    0.124138
# PHM    0.096982
# WRK    0.067348
# SEN    0.034630
# SCH    0.018722
# MIL    0.016675
# Name: V_ADMINBY, dtype: float64
#
# No. of missing/NaN for V_ADMINBY out of 169537 rows: 0 rows
# % missing/NaN for V_ADMINBY out of 169537 rows: 0.0 %

# %%
plot_cat(
    df = df, 
    col = 'V_ADMINBY', 
    hue = 'TARGET_SERIOUS_ADVERSE',
    figsize=(12,8)
)

# %%
# Checking counts after grouping by V_ADMINBY:

df.groupby('V_ADMINBY').\
TARGET_SERIOUS_ADVERSE.\
value_counts().\
rename('Counts').\
reset_index()
# Out:
#    V_ADMINBY TARGET_SERIOUS_ADVERSE  Counts
# 0        MIL                     No    2121
# 1        MIL                    Yes     706
# 2        OTH                     No   23742
# 3        OTH                    Yes    5081
# 4        PHM                     No   13941
# 5        PHM                    Yes    2501
# 6        PUB                     No   19261
# 7        PUB                    Yes    4099
# 8        PVT                     No   43642
# 9        PVT                    Yes   12934
# 10       SCH                     No    2704
# 11       SCH                    Yes     470
# 12       SEN                     No    3957
# 13       SEN                    Yes    1914
# 14       UNK                     No   17210
# 15       UNK                    Yes    3836
# 16       WRK                     No    9448
# 17       WRK                    Yes    1970

# %%
adminby_p = df.groupby('V_ADMINBY').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
adminby_p
# Out:
#    V_ADMINBY TARGET_SERIOUS_ADVERSE  proportion
# 0        MIL                     No    0.750265
# 1        MIL                    Yes    0.249735
# 2        OTH                     No    0.823717
# 3        OTH                    Yes    0.176283
# 4        PHM                     No    0.847890
# 5        PHM                    Yes    0.152110
# 6        PUB                     No    0.824529
# 7        PUB                    Yes    0.175471
# 8        PVT                     No    0.771387
# 9        PVT                    Yes    0.228613
# 10       SCH                     No    0.851922
# 11       SCH                    Yes    0.148078
# 12       SEN                     No    0.673991
# 13       SEN                    Yes    0.326009
# 14       UNK                     No    0.817733
# 15       UNK                    Yes    0.182267
# 16       WRK                     No    0.827465
# 17       WRK                    Yes    0.172535

# %%
plot_bar(
    df = adminby_p, 
    x = 'V_ADMINBY',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients who experienced least 1 serious adverse side effect, grouped by type of vaccine facility',
    figsize=(12,8)
)

# %% [markdown]
# From data dictionary: Type of facility where vaccine was administered. The reporter may note on the VAERS form the type of facility administering the vaccine.
#
# The options are different depending on the form version; additional options were added on the VAERS 2 form. <br>
#
# VAERS 1.0: PUB=Public, PVT=Private, MIL=Military, OTH=Other, UNK=Unknown <br>
# VAERS 2.0: PUB=Public, PVT=Private, MIL=Military, PHM=Pharmacy or store, SCH=School or student health clinic, SEN=Nursing home or senior living facility, WRK=Workplace clinic, OTH=Other, UNK=Unknown
#
#
# It is likely that those who had their vaccines administered at the nursing home were also older and much sicker (hence they had to be placed in a nursing home/senior home) in the first place.
#
# This is probably the only surrogate feature of the sicker patients that we have at the moment.

# %%
check_cat(df, 'NUR_HOME')
# Out:
# Counts for each category for NUR_HOME out of 2 categories:
# No     163666
# Yes      5871
# Name: NUR_HOME, dtype: int64
#
# proportion for each category for NUR_HOME out of 2 categories:
# No     0.96537
# Yes    0.03463
# Name: NUR_HOME, dtype: float64
#
# No. of missing/NaN for NUR_HOME out of 169537 rows: 0 rows
# % missing/NaN for NUR_HOME out of 169537 rows: 0.0 %

# %% [markdown]
# ## Target_vs_gender

# %%
check_cat(df, 'SEX')
# Out:
# Counts for each category for SEX out of 3 categories:
# F    131952
# M     36962
# U       623
# Name: SEX, dtype: int64
#
# proportion for each category for SEX out of 3 categories:
# F    0.778308
# M    0.218017
# U    0.003675
# Name: SEX, dtype: float64
#
# No. of missing/NaN for SEX out of 169537 rows: 0 rows
# % missing/NaN for SEX out of 169537 rows: 0.0 %

# %% [markdown]
# From data dictionary: Sex - Sex of the vaccine recipient (M = Male, F = Female, Unknown = Blank).

# %%
# Checking proportions: 

gender_p = df.groupby('SEX').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
gender_p
# Out:
#   SEX TARGET_SERIOUS_ADVERSE  proportion
# 0   F                     No    0.815206
# 1   F                    Yes    0.184794
# 2   M                     No    0.756994
# 3   M                    Yes    0.243006
# 4   U                     No    0.767255
# 5   U                    Yes    0.232745

# %%
plot_bar(
    df = gender_p, 
    x = 'SEX',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients who experienced least 1 serious adverse side effect, grouped by gender',
    figsize=(16,6)
)

# %% [markdown]
# ### Impute_missing/U_gender_as_F
#
# From data dictionary: Sex - Sex of the vaccine recipient (M = Male, F = Female, Unknown = Blank).
#
# From the above, the missing/Unknown cases are more similar to female than male - we can impute these missing values for sex as F

# %%
df['SEX'] = df['SEX'].replace(to_replace = {'U': 'F'})

# %%
check_cat(df, 'SEX')
# Out:
# Counts for each category for SEX out of 2 categories:
# F    132575
# M     36962
# Name: SEX, dtype: int64
#
# proportion for each category for SEX out of 2 categories:
# F    0.781983
# M    0.218017
# Name: SEX, dtype: float64
#
# No. of missing/NaN for SEX out of 169537 rows: 0 rows
# % missing/NaN for SEX out of 169537 rows: 0.0 %

# %%
# Re-checking proportions

gender_p = df.groupby('SEX').\
    TARGET_SERIOUS_ADVERSE.\
    value_counts(normalize=True).\
    rename('proportion').\
    reset_index()

# %%
gender_p
# Out:
#   SEX TARGET_SERIOUS_ADVERSE  proportion
# 0   F                     No    0.814980
# 1   F                    Yes    0.185020
# 2   M                     No    0.756994
# 3   M                    Yes    0.243006

# %%
plot_bar(
    df = gender_p, 
    x = 'SEX',
    y = 'proportion',
    hue = 'TARGET_SERIOUS_ADVERSE',
    title = 'Proportion of patients who experienced least 1 serious adverse side effect, grouped by gender',
    figsize=(16,6)
)

# %% [markdown]
# ## Target_vs_AGE_YRS_vs_SEX

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'AGE_YRS',
    hue = 'SEX', 
    figsize= (12,8)
)

# %% [markdown]
# ## Target_vs_STATE

# %%
check_cat(df, 'STATE')
# Out:
# Counts for each category for STATE out of 63 categories:
# CA    16663
# NY     9519
# TX     9373
# FL     9043
# IN     8868
#       ...
# QM        1
# XL        1
# XB        1
# Ca        1
# XV        1
# Name: STATE, Length: 63, dtype: int64
#
# proportion for each category for STATE out of 63 categories:
# CA    0.107840
# NY    0.061605
# TX    0.060660
# FL    0.058525
# IN    0.057392
#         ...
# QM    0.000006
# XL    0.000006
# XB    0.000006
# Ca    0.000006
# XV    0.000006
# Name: STATE, Length: 63, dtype: float64
#
# No. of missing/NaN for STATE out of 169537 rows: 15021 rows
# % missing/NaN for STATE out of 169537 rows: 9.0 %

# %%
plt.figure(figsize=(18,6))
sns.countplot(x='STATE', data=df, hue='TARGET_SERIOUS_ADVERSE');

# %% [markdown]
# Including this variable would mean introducing too much noise without any clear underlying theoretical link between a patient experiencing at least 1 vaccine-related serious adverse side effect and the US state they were in. To drop.

# %% [markdown]
# ## Target_vs_NUMDAYS_CAL

# %%
check_continuous(df, 'NUMDAYS_CAL')
# Out:
# count    169537.000000
# mean          2.836508
# std           5.618584
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          93.000000
# Name: NUMDAYS_CAL, dtype: float64
# No. of missing/NaN for NUMDAYS_CAL out of 169537 rows: 0 rows
# % missing/NaN for NUMDAYS_CAL out of 169537 rows: 0.0 %

# %% [markdown]
# - This particular dataset only contains information about mRNA vaccines.
# - [The half-life of the mRNA is short and remains in human tissues for just a few days](https://pssjournal.biomedcentral.com/articles/10.1186/s13037-021-00291-9)
# - most patients experience symptoms within 7 -10 days. Symptoms experienced after that are less likely to be attributable to the vaccine per se, and would represent other causes. The outlier values from 10 to 76 days likely represent the same underlying construct of 'other causes' for symptoms.
# - we can therefore clip the upper limit of this variable

# %%
df['NUMDAYS_CAL_CLIP'] = df['NUMDAYS_CAL'].clip(upper=10)

# %%
check_continuous(df, 'NUMDAYS_CAL_CLIP')
# Out:
# count    169537.000000
# mean          2.269888
# std           3.238091
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          10.000000
# Name: NUMDAYS_CAL_CLIP, dtype: float64
# No. of missing/NaN for NUMDAYS_CAL_CLIP out of 169537 rows: 0 rows
# % missing/NaN for NUMDAYS_CAL_CLIP out of 169537 rows: 0.0 %

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'NUMDAYS_CAL_CLIP',
    figsize= (12,8)
)

# %% [markdown]
# ## Target_vs_COUNT_SYMPT

# %%
check_continuous(df, 'COUNT_SYMPT')
# Out:
# count    169537.000000
# mean          4.669966
# std           3.505827
# min           1.000000
# 25%           2.000000
# 50%           5.000000
# 75%           6.000000
# max         101.000000
# Name: COUNT_SYMPT, dtype: float64
# No. of missing/NaN for COUNT_SYMPT out of 169537 rows: 0 rows
# % missing/NaN for COUNT_SYMPT out of 169537 rows: 0.0 %

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'COUNT_SYMPT',
    figsize= (12,8)
)

# %% [markdown]
# - The range for this variable is from 1 to 101.
# - Upon exploration in the [inital EDA](Initial_sanity_checks_combined_dataset.ipynb), these outlier COUNT_SYMP values contained a mix of laboratory test and imaging-related results rather than reported symptoms. These are a result of complications arising from the medical management of these patients.
# - The outlier values from 20 - 101 are likely attributable to the patient's comorbidities and medical management, rather than vaccine-related. They likely represent the same underlying construct of 'medical complications'
# - We can therefore clip the upper limit of these variables

# %%
df['COUNT_SYMPT_CLIP'] = df['COUNT_SYMPT'].clip(upper=20)

# %%
check_continuous(df, 'COUNT_SYMPT_CLIP')
# Out:
# count    169537.000000
# mean          4.627055
# std           3.137431
# min           1.000000
# 25%           2.000000
# 50%           5.000000
# 75%           6.000000
# max          20.000000
# Name: COUNT_SYMPT_CLIP, dtype: float64
# No. of missing/NaN for COUNT_SYMPT_CLIP out of 169537 rows: 0 rows
# % missing/NaN for COUNT_SYMPT_CLIP out of 169537 rows: 0.0 %

# %%
df.COUNT_SYMPT_CLIP.value_counts()
# Out:
# 5     46375
# 3     28919
# 2     26670
# 1     21701
# 6     13955
# 7      9630
# 10     7695
# 8      6688
# 11     2266
# 12     1445
# 15     1288
# 13     1064
# 20      930
# 16      388
# 17      289
# 18      220
# 4         8
# 9         5
# 14        1
# Name: COUNT_SYMPT_CLIP, dtype: int64

# %%
plot_box(
    df = df,
    x = 'TARGET_SERIOUS_ADVERSE',
    y = 'COUNT_SYMPT_CLIP',
    figsize= (12,8)
)

# %% [markdown]
# # Correlation matrix

# %% [markdown]
# Checking correlations between numeric features

# %%
fig, ax = plt.subplots(figsize=(12,12))
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm', center=0, annot=True, ax=ax,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %% [markdown]
# # Drop columns not needed for modelling

# %%
DROP_COLS =  [
    'VAERS_ID',
    'STATE',
    'SYMPTOM_TEXT',
    'DIED',
    'L_THREAT',
    'HOSPITAL',
    'HOSPDAYS',
    'X_STAY',
    'DISABLE',
    'RECOVD',
    'VAX_DATE',
    'ONSET_DATE',
    'NUMDAYS',
    'LAB_DATA',
    'OTHER_MEDS',
    'CUR_ILL',
    'HISTORY',
    'PRIOR_VAX',
    'SPLTTYPE',
    'OFC_VISIT',
    'ER_ED_VISIT',
    'ALLERGIES',
    'SYMP',
    'SYMP_DEATH', 
    'SYMP_CARDIAC',
    'SYMP_SERIOUS_ALLERGY',
    'V_ADMINBY',
    'RECVDATE',
    'CAGE_YR',
    'CAGE_MO',
    'DATEDIED',
    'ER_VISIT',
    'V_FUNDBY',
    'FORM_VERS',
    'TODAYS_DATE',
    'RPT_DATE',
    'BIRTH_DEFECT',
    'composite'
]

df_dropped = df.drop(labels=DROP_COLS, axis=1)

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169537 entries, 0 to 169536
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   AGE_YRS                 169537 non-null  float64
#  1   SEX                     169537 non-null  object
#  2   VAX_MANU                169537 non-null  object
#  3   COUNT_SYMPT             169537 non-null  int64
#  4   NUMDAYS_CAL             169537 non-null  int64
#  5   HISTORY_DUM             169537 non-null  category
#  6   ALLERGIES_DUM           169537 non-null  category
#  7   HYPERTENSION            169537 non-null  category
#  8   DIABETES                169537 non-null  category
#  9   CANCER                  169537 non-null  category
#  10  CKD                     169537 non-null  category
#  11  CARDIOVASCULAR          169537 non-null  category
#  12  NUR_HOME                169537 non-null  category
# ...

# %% [markdown]
# # Pairplots

# %%
sns.pairplot(df_dropped, hue = 'TARGET_SERIOUS_ADVERSE')
